# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
xls = pd.read_excel('Sector Telecomunicaciones.xls',header=5)

# %%
xls.last_valid_index()
# Out:
# 2531

# %%
xls
# Out:
#                                         Effective date   \
# 0                                   2009-04-30 00:00:00
# 1                                   2009-05-04 00:00:00
# 2                                   2009-05-05 00:00:00
# 3                                   2009-05-06 00:00:00
# 4                                   2009-05-07 00:00:00
# 5                                   2009-05-08 00:00:00
# 6                                   2009-05-11 00:00:00
# 7                                   2009-05-12 00:00:00
# 8                                   2009-05-13 00:00:00
# 9                                   2009-05-14 00:00:00
# 10                                  2009-05-15 00:00:00
# 11                                  2009-05-18 00:00:00
# 12                                  2009-05-19 00:00:00
# 13                                  2009-05-20 00:00:00
# 14                                  2009-05-21 00:00:00
# 15                                  2009-05-22 00:00:00
# ...

# %%
ppp = (xls["S&P/BMV Telecommunication Services Sector Index TR"].last_valid_index())+1

# %%
telecomunication = xls.iloc[0:ppp,[0,2]]

# %%
max(telecomunication['S&P/BMV Telecommunication Services Sector Index'])
# Out:
# 1039.48

# %%
plt.plot(telecomunication['S&P/BMV Telecommunication Services Sector Index'])
plt.show()
